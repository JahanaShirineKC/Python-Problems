# %%
a = [1,2,3,4,5]

# %%
import numpy as np
arr = np.array(a)
print(arr)
print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
matr_zero = np.zeros((2,3))
print(matr_zero)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
matr_ones = np.ones((2,3))
print(matr_ones)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
print(np.arange(1,10,2))
# Out:
# [1 3 5 7 9]

# %%
print(np.arange(1,10))
# Out:
# [1 2 3 4 5 6 7 8 9]

# %%
print(np.linspace(0,1,5))
# Out:
# [0.   0.25 0.5  0.75 1.  ]
